# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + support us if you can!
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth#installation-instructions---conda).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).
#
# See on our [blog post](https://unsloth.ai/blog/gemma) on how we made **Gemma 7b 2.5x faster** and **Gemma 2b 2x faster**!

# %%
#%%capture
import logging
from datetime import datetime
import sys
import os

# Obtener la fecha y hora actual
fecha_hora_actual = datetime.now()

# Crear un logger
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# Crear un manejador para la consola
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.DEBUG)

# Formatear la fecha y hora
texto_fecha_hora = fecha_hora_actual.strftime("%Y%m%d_%H%M")
mylog = "comebien_"+texto_fecha_hora+".log"

# Crear un manejador para el archivo
file_handler = logging.FileHandler(filename=mylog)
file_handler.setLevel(logging.DEBUG)

# Definir el formato de los registros
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
console_handler.setFormatter(formatter)
file_handler.setFormatter(formatter)

# Agregar los manejadores al logger
logger.addHandler(console_handler)
logger.addHandler(file_handler)
logger.info('Comienzo de script')
# !git config --global credential.helper store
# !pip install wandb
import os
import wandb
wandb.login()

import torch
major_version, minor_version = torch.cuda.get_device_capability()
# Must install separately since Colab has torch 2.2.1, which breaks packages
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
if major_version >= 8:
    # Use this for new GPUs like Ampere, Hopper GPUs (RTX 30xx, RTX 40xx, A100, H100, L40)
    # !pip install --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
else:
    # Use this for older GPUs (V100, Tesla T4, RTX 20xx)
    # !pip install --no-deps xformers trl peft accelerate bitsandbytes
pass
print('End of pip install')
# Out:
# 2024-04-08 22:16:15,616 - INFO - Comienzo de script
# ...
#      |████████████████████████████████| 2.2 MB 20.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 32.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 266 kB 103.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 294 kB 102.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 207 kB 103.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 62 kB 7.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 121 kB 99.1 MB/s eta 0:00:01
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.6
#     Uninstalling urllib3-1.26.6:
#       Successfully uninstalled urllib3-1.26.6
# ...
# 2024-04-08 22:16:23,104 - DEBUG - Popen(['git', 'version'], cwd=/data, stdin=None, shell=False, universal_newlines=False)
# 2024-04-08 22:16:23,112 - DEBUG - Popen(['git', 'version'], cwd=/data, stdin=None, shell=False, universal_newlines=False)
# ...

# %%
#from huggingface_hub import notebook_login
#notebook_login()

#my_run = "mistral7biv02_2""
#my_run = "gemma-2b-it-bnb-4bit"
# 23/03/24 my_run = "mistral-7b-instruct-v0.2-bnb-4bit" 
# 24/03/2024 Error con my_run = "gemma-7b-it-bnb-4bit"
# 28/03/2024 Ok 60 steps "llama-2-7b-bnb-4bit"
# 28/03/24 ok 60 "mistral-7b-instruct-v0.2-bnb-4bit"
# 29/03/24 ok 2000 1h "gemma-2b-it-bnb-4bit"
# 05/05/24 ok 10 epocs 100 items  "gemma-2b-it-bnb-4bit"
my_run = "gemma-2b-bnb-4bit"

my_max_steps = 400
my_train_epochs = 9
my_unsloth_model_name = "unsloth/" + my_run
#my_generated_model_name = "ComeBien_Ing_" + my_run
#my_generated_model_name = "ComeBien_DIXREC10_" + my_run
#my_generated_model_name = "ComeBien_Nutr100_" + my_run
#my_generated_model_name = "ComeBien_Nutricional_" + my_run
my_generated_model_name = "RecetasDeLaAbuela5k_" + my_run
my_generated_model = "somosnlp/" + my_generated_model_name

#my_data_files = 'recetasabuela_DIXREC10_gemma.csv'
#my_data_files = 'recetasabuela_Nutr_gemma.csv'
my_data_files = 'recetasabuela_es.csv'
#my_processed_data_files = 'recetasabuela_DIXREC10_gemma_ds.csv'
my_processed_data_files = 'recetasabuela_es_ds.csv'
#my_data_files = 'RecetasDeLaAbuela_Ingredientes.csv'
#my_processed_data_files = 'RecetasDeLaAbuela_Ingredientes_ds.csv'

#os.environ["WANDB_PROJECT"] = "Recetas20kTest21_Ingredientes_" + my_run   # name your W&B project
#os.environ["WANDB_PROJECT"] = "Recetas20kTest22_ComeBien_Nutr3_" + my_run   # name your W&B project
#os.environ["WANDB_PROJECT"] = "Recetas20kTest22_ComeBien_Nutr4_" + my_run   # name your W&B project
os.environ["WANDB_PROJECT"] = "RecetasDeLaAbuela5k_" + my_run   # name your W&B project
os.environ["WANDB_LOG_MODEL"] = "checkpoint"  # log all model checkpoints
wandb.login()

logger.info('Iniciando entrenamiento LLM sobre modelo '+my_unsloth_model_name)
# Out:
# wandb: Currently logged in as: roverico. Use `wandb login --relogin` to force relogin
# 2024-04-08 22:18:33,861 - INFO - Iniciando entrenamiento LLM sobre modelo unsloth/gemma-2b-bnb-4bit

# %% [markdown]
# * We support Llama, Mistral, CodeLlama, TinyLlama, Vicuna, Open Hermes etc
# * And Yi, Qwen ([llamafied](https://huggingface.co/models?sort=trending&search=qwen+llama)), Deepseek, all Llama, Mistral derived archs.
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * [**NEW**] With [PR 26037](https://github.com/huggingface/transformers/pull/26037), we support downloading 4bit models **4x faster**! [Our repo](https://huggingface.co/unsloth) has Llama, Mistral 4bit models.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 4096 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",
    "unsloth/gemma-7b-it-bnb-4bit", # Instruct version of Gemma 7b
    "unsloth/gemma-2b-bnb-4bit",
    "unsloth/gemma-2b-it-bnb-4bit", # Instruct version of Gemma 2b
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = my_unsloth_model_name, # Choose ANY! eg teknium/OpenHermes-2.5-Mistral-7B
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
logger.info('Componiendo modelo %s', model)
# Out:
# 2024-04-08 22:18:35,716 - DEBUG - Starting new HTTPS connection (1): huggingface.co:443
# 2024-04-08 22:18:35,745 - DEBUG - https://huggingface.co:443 "HEAD /unsloth/gemma-2b-bnb-4bit/resolve/main/config.json HTTP/1.1" 200 0
# 2024-04-08 22:18:35,747 - DEBUG - Attempting to acquire lock 140070835986976 on /home/user/.cache/huggingface/hub/.locks/models--unsloth--gemma-2b-bnb-4bit/884922c016ef5747c8748c38e22453866d28bfdb.lock
# 2024-04-08 22:18:35,748 - DEBUG - Lock 140070835986976 acquired on /home/user/.cache/huggingface/hub/.locks/models--unsloth--gemma-2b-bnb-4bit/884922c016ef5747c8748c38e22453866d28bfdb.lock
# 2024-04-08 22:18:35,762 - DEBUG - https://huggingface.co:443 "GET /unsloth/gemma-2b-bnb-4bit/resolve/main/config.json HTTP/1.1" 200 1107
# config.json:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# ...

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
from peft import LoftQConfig
loftq_config = LoftQConfig(loftq_bits=4)
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # 16 Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32, # 16
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = True,
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None #loftq_config, # And LoftQ
)
# Out:
# Unsloth 2024.4 patched 18 layers with 18 QKV layers, 18 O layers and 18 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Alpaca dataset from [yahma](https://huggingface.co/datasets/yahma/alpaca-cleaned), which is a filtered version of 52K of the original [Alpaca dataset](https://crfm.stanford.edu/2023/03/13/alpaca.html). You can replace this code section with your own data prep.
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# If you want to use the `ChatML` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing).
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

gemma_prompt = """<bos><start_of_turn>system {}<end_of_turn><start_of_turn>user {}<end_of_turn><start_of_turn>model"""


EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_alpaca_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass
def formatting_gemma_prompts_func(examples):
    #instructions = examples["instruction"]
    nombres        = examples["Nombre"]
    #outputs      = examples["Valor nutricional"]
    ingredientes  = examples["Ingredientes"]
    pasos         = examples["Pasos"]
    texts = []
    #for instruction, input, output in zip(instructions, inputs, outputs):
    for nombre, ingrediente, paso in zip(nombres, ingredientes, pasos):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        #instruction = "You are a technical specialist in food and cooking. Dime en español los ingredientes de la siguiente receta "
        #text = gemma_prompt.format(instruction, input, output) + EOS_TOKEN
        #instruction = 'You are a helpful AI assistant. Eres un agente experto en nutrición y cocina. Lista de codigos linguisticos disponibles: [''es'', ''en''].'
        instruction = 'Eres un agente experto en nutrición y cocina.'
        #input = 'Cantidad de calorías, grasas, sodio, azúcar de la receta ' + input
        nombre = 'Ingredientes y pasos de la receta ' + nombre
        receta = 'Ingredientes: ' + ingrediente + '. Pasos: ' + paso
        text = f'''<bos><start_of_turn>system\n{instruction}<end_of_turn><start_of_turn>user\n{nombre}<end_of_turn><start_of_turn>model\n{receta}<end_of_turn>''' + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

from datasets import load_dataset
#dataset = load_dataset("yahma/alpaca-cleaned", split = "train")
logger.info('Loading dataset...')
dataset = load_dataset('csv', data_files=my_data_files, split="train", encoding='utf-8')
dataset = dataset.map(formatting_gemma_prompts_func, batched = True,)
dataset.to_csv(my_processed_data_files)
logger.info('End of loading dataset')
# Out:
# 2024-04-08 22:19:28,035 - INFO - Loading dataset...
# 2024-04-08 22:19:28,039 - DEBUG - Starting new HTTPS connection (1): s3.amazonaws.com:443
# 2024-04-08 22:19:28,074 - DEBUG - https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/datasets/csv/csv.py HTTP/1.1" 200 0
# 2024-04-08 22:19:28,079 - DEBUG - Attempting to acquire lock 140063719220608 on /home/user/.cache/huggingface/datasets/_home_user_.cache_huggingface_datasets_csv_default-c4435c3ad326dd0c_0.0.0_2c2bba169a7e870eb2bcc07f2c69b72b171db4933b1c2e2833d2b48aeaf2f6c6.lock
# 2024-04-08 22:19:28,080 - DEBUG - Lock 140063719220608 acquired on /home/user/.cache/huggingface/datasets/_home_user_.cache_huggingface_datasets_csv_default-c4435c3ad326dd0c_0.0.0_2c2bba169a7e870eb2bcc07f2c69b72b171db4933b1c2e2833d2b48aeaf2f6c6.lock
# ...

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
logger.info('Defining SFT Training ...')
def compute_metrics(p):    
    pred, labels = p
    pred = np.argmax(pred, axis=1)
    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred)
    precision = precision_score(y_true=labels, y_pred=pred)
    f1 = f1_score(y_true=labels, y_pred=pred)    
    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    compute_metrics = compute_metrics,
    #callbacks = [EarlyStoppingCallback(early_stopping_patience=3),],
    args =TrainingArguments(
        report_to = "wandb", # enables logging to W&B 
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        #max_steps = my_max_steps,
        num_train_epochs = my_train_epochs,
        learning_rate = 2e-4, #5e-5, # 2e-4
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        #evaluation_strategy = "steps",
        #eval_steps = 20,
        logging_strategy = "steps",
        logging_steps = 10,
        save_strategy = "steps",
        save_steps = 100,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine", # linear
        seed = 3408,
        output_dir = "outputs",        
        #metric_for_best_model = 'f1',
        #load_best_model_at_end = True,
    )
)
#logging.info('SFT ', str(my_args))
# Out:
# 2024-04-08 22:19:50,891 - INFO - Defining SFT Training ...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Map (num_proc=2):   0%|          | 0/2256 [00:00<?, ? examples/s]
# 2024-04-08 22:19:54,053 - DEBUG - open file: /home/user/.cache/huggingface/datasets/csv/default-c4435c3ad326dd0c/0.0.0/2c2bba169a7e870eb2bcc07f2c69b72b171db4933b1c2e2833d2b48aeaf2f6c6/tmp4ep0x7gj
# ...

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
logger.info(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
logger.info(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# 2024-04-08 22:19:54,925 - INFO - GPU = Tesla T4. Max memory = 14.581 GB.
# 2024-04-08 22:19:54,927 - INFO - 2.352 GB of memory reserved.

# %%
# Execute training
resume_from_checkpoint = True
if resume_from_checkpoint:
    logger.info('Resume training...')
    trainer_stats = trainer.train(resume_from_checkpoint=resume_from_checkpoint)
else:
    logger.info('Start of training...')
    trainer_stats = trainer.train()
logger.info('End of training')
# Out:
# 2024-04-08 22:19:54,932 - INFO - Resume training...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 2,256 | Num Epochs = 9
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 2,538
#  "-____-"     Number of trainable parameters = 19,611,648
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/data/wandb/run-20240408_221955-yarpvc3g</code>
# ...

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
logger.info(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
logger.info(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
logger.info(f"Peak reserved memory = {used_memory} GB.")
logger.info(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
logger.info(f"Peak reserved memory % of max memory = {used_percentage} %.")
logger.info(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 2024-04-08 22:42:44,604 - INFO - 1367.6879 seconds used for training.
# 2024-04-08 22:42:44,606 - INFO - 22.79 minutes used for training.
# 2024-04-08 22:42:44,607 - INFO - Peak reserved memory = 12.807 GB.
# 2024-04-08 22:42:44,608 - INFO - Peak reserved memory for training = 10.455 GB.
# 2024-04-08 22:42:44,609 - INFO - Peak reserved memory % of max memory = 87.833 %.
# 2024-04-08 22:42:44,610 - INFO - Peak reserved memory for training % of max memory = 71.703 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
# alpaca_prompt = Copied from above
from transformers import TextStreamer, GenerationConfig
#logger.info('Probando recetas...')
#FastLanguageModel.for_inference(model) # Enable native 2x faster inference
#instruction = "You are a technical specialist in food and cooking. Dime en español el valor nutricional de la siguiente receta "
instruction = 'Eres un agente experto en nutrición y cocina. Dime los ingredientes y pasos de la receta '

def generate_answer(input, instruction, gemma_prompt, model, logger):
    inputs = tokenizer([gemma_prompt.format(instruction, input,"",)], return_tensors = "pt").to("cuda")   
    text_streamer = TextStreamer(tokenizer)
    generation_config = GenerationConfig(max_new_tokens=400,
                temperature=0.32, #top_p=0.9, top_k=50, # 45
                repetition_penalty=1.3,  #1.1 #1.04
                do_sample=True,
    )
    outputs = model.generate(**inputs, streamer = text_streamer, generation_config = generation_config)
    #outputs = model.generate(**inputs, max_new_tokens = 256, use_cache = True)
    output = tokenizer.batch_decode(outputs)
    logger.info(output)

generate_answer('cocido de garbanzos', instruction, gemma_prompt, model, logger)
#generate_answer('frijoles', instruction, gemma_prompt, model, logger)
#generate_answer('ceviche', instruction, gemma_prompt, model, logger)
#generate_answer('enchiladas mexicanas', instruction, gemma_prompt, model, logger)
# Out:
# <bos><bos><start_of_turn>system Eres un agente experto en nutrición y cocina. Dime los ingredientes y pasos de la receta <end_of_turn><start_of_turn>user cocido de garbanzos<end_of_turn><start_of_turn>model Un día frío te pides unas recetas para Navidad o Año Nuevo con una comida caliente porque así es mejor. Y si lo que quieres son platos completos pero diferentes a las tradicional tapas al horno como el sándwich asado por ejemplo no dejes de probar este plato típico español de legumbres ¡te encantará!' mascarpone queso fresco jamón serrano cebolla... ¿Te animas? A continuación tienes todos los detalles técnicos del guiso de garbanzos:Tipo de cocción Tiempo de preparación Pasos Ingredientes paso-a-paso Entra dentro de cada uno de estos túneles donde encontrarás todas las indicaciones necesarias para preparar tu propio plato tanto si prefieres hacerlo todo manual como si decidas usar algún tipo de maquinaria eléctrica. Truco: Puedes sustituir el pimiento rojo por verde aunque nosotro
# ...

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
# alpaca_prompt = Copied from above
#FastLanguageModel.for_inference(model) # Enable native 2x faster inference
#inputs = tokenizer(
#[
#    gemma_prompt.format(
#        instruction,
#        "tortilla de patatas", # input
#        "", # output - leave this blank for generation!
#    )
#], return_tensors = "pt").to("cuda")

#from transformers import TextStreamer
#text_streamer = TextStreamer(tokenizer)
#_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 256)

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
#model.save_pretrained("lora_model") # Local saving
model.save_pretrained(my_generated_model_name) # Local saving
model.push_to_hub(my_generated_model, token = "xxxx") # Online saving
logger.info('Model saved to FH' + my_generated_model)
# Out:
# 2024-04-08 22:43:31,227 - DEBUG - https://huggingface.co:443 "HEAD /unsloth/gemma-2b-bnb-4bit/resolve/main/config.json HTTP/1.1" 200 0
# 2024-04-08 22:43:31,238 - DEBUG - https://huggingface.co:443 "HEAD /unsloth/gemma-2b-bnb-4bit/resolve/main/config.json HTTP/1.1" 200 0
# 2024-04-08 22:43:31,557 - DEBUG - https://huggingface.co:443 "POST /api/repos/create HTTP/1.1" 409 125
# 2024-04-08 22:43:31,577 - DEBUG - https://huggingface.co:443 "POST /api/repos/create HTTP/1.1" 409 125
# 2024-04-08 22:43:31,651 - DEBUG - https://huggingface.co:443 "HEAD /somosnlp/RecetasDeLaAbuela5k_gemma-2b-bnb-4bit/resolve/main/README.md HTTP/1.1" 200 0
# 2024-04-08 22:43:31,653 - DEBUG - Attempting to acquire lock 140062601212352 on /home/user/.cache/huggingface/hub/.locks/models--somosnlp--RecetasDeLaAbuela5k_gemma-2b-bnb-4bit/d1fbf794b00005e4d01dc203d9413658fa8809e8.lock
# ...

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = my_generated_model, # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer
    model = AutoPeftModelForCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. `ChatML` for ShareGPT datasets, [conversational notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing)
# 8. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
